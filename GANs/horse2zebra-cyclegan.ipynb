jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_10131.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_2477.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_2585.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_10504.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_2061.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_7678.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_10239.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_6622.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_956.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_3053.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_743.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_1172.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_536.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_178.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_2018.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_2603.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_2746.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_9965.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_1178.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_279.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_7836.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_501.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_4069.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_9365.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_2163.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_428.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_7038.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_5637.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_659.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_1495.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_2784.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_1099.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_757.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_5889.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_3681.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_11128.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_3034.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_10467.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_2366.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_10158.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_3371.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_2364.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_295.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_10278.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_2758.jpg
# /kaggle/input/horse2zebra-dataset/trainB/n02391049_2524.jpg
# ...
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2755.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1713.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1793.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2783.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1852.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2091.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_601.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_3265.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_5674.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_631.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1048.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_798.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1135.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_8944.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_3638.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4637.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2349.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_8179.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_3588.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_3412.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_598.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4312.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4785.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1521.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_5892.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_477.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_3989.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4991.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_3566.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4946.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_6792.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1651.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_3732.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1388.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_5704.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4385.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1338.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_5805.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2578.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_5287.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4967.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_627.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4815.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_5442.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_5408.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_3192.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_7845.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_6402.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1319.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1509.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_769.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_5029.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_767.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_3182.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2612.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_8527.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_5167.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1134.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2968.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_6941.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1191.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_376.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1761.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1562.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2275.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1751.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_757.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_3358.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_108.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1106.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4621.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_177.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4465.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_8611.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_784.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1184.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1973.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_501.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4395.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_6335.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2685.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4711.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4425.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1484.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_8577.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2449.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_6944.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_7858.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2563.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_5396.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4613.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_5869.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_3556.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_6289.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4536.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_437.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_9127.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1168.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4597.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_5699.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2152.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_5878.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_6152.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_91.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_3365.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_5819.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2806.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_7942.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2043.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_3113.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1526.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_565.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_61.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_3107.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_424.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_3997.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2198.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_196.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_419.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4748.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1798.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_743.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4123.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_939.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2306.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1995.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4429.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1001.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1019.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_558.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1639.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2753.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_7495.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_8389.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_509.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_879.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2799.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_697.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_3854.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_7219.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4551.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_155.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1847.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_717.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1703.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2141.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2643.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2951.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_3656.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4674.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4977.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_911.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_863.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1959.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_739.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_6388.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_993.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1014.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1132.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_6824.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1991.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_5156.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_8958.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4401.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1519.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2788.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2484.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2594.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1531.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1159.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_3329.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_422.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4413.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_9234.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_8877.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_7398.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_3442.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4661.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1856.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_912.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_901.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_3664.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_6294.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4602.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_8769.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2476.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2754.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_357.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_9184.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_122.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4276.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_594.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1023.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4376.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4965.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1068.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_7806.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_7622.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_804.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_3827.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_3935.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_7165.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1801.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_7456.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1803.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_69.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4521.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2564.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2177.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_5545.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2509.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4371.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1675.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_3928.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_7515.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2929.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_503.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1493.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2995.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2555.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_3354.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4779.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1297.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1034.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_3685.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1581.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_807.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_7919.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4501.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1796.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1028.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4374.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_195.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4112.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2802.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_7888.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_691.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_8838.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4055.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_3995.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_777.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1197.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1122.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_856.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2374.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_3001.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2259.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_4975.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_5292.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1937.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2261.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_3283.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_7803.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_8626.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1426.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_6721.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1721.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_5804.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_203.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_755.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_6822.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_919.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_5944.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_9167.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_1365.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2269.jpg
# /kaggle/input/horse2zebra-dataset/trainA/n02381460_2598.jpg

# %%
import torch
import torch.nn as nn

# %%
from torch.utils.data import Dataset
from PIL import Image

# %%
from torch.utils.data import DataLoader
import torch.optim as optim
from tqdm import tqdm
from torchvision.utils import save_image

# %%
import albumentations as A
from albumentations.pytorch import ToTensorV2
import random

# %%
class Block(nn.Module):
    def __init__(self, in_channels, out_channels, strides):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 4, strides, 1, bias=True, padding_mode="reflect"),
            nn.LeakyReLU(0.2)
        )
        
    def forward(self, x):
        return self.conv(x)

# %%
class Discriminator(nn.Module):
    def __init__(self, in_channels=3, features=[64, 128, 256, 512]):
        super().__init__()
        self.initial = nn.Sequential(
            nn.Conv2d(in_channels, features[0], kernel_size=4, stride=2, padding=1, padding_mode="reflect"),
            nn.LeakyReLU(0.2),
        )

        layers = []
        in_channels = features[0]
        for feature in features[1:]:
            layers.append(
                Block(in_channels, feature, strides=1 if feature == features[-1] else 2)
            )
            in_channels = feature
        
        layers.append(
            nn.Conv2d(in_channels, 1, kernel_size=4, stride=1, padding=1, padding_mode="reflect")
        )
    
        self.model = nn.Sequential(*layers)

    def forward(self, x):
        x = self.initial(x)
        return torch.sigmoid(self.model(x))

# %%
def test():
    x= torch.randn((5, 3, 256, 256))
    model=Discriminator()
    preds=  model(x)
    print(preds.shape)
    
test()
# Out:
# torch.Size([5, 1, 30, 30])

# %%
class ConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels, down=True, use_act=True, **kwargs):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, padding_mode="reflect", **kwargs)
            if down
            else nn.ConvTranspose2d(in_channels, out_channels, **kwargs),
            nn.InstanceNorm2d(out_channels),
            nn.ReLU(inplace=True) if use_act else nn.Identity()
        )
    
    def forward(self, x):
        return self.conv(x)

    
class ResidualBlock(nn.Module):
    def __init__(self, channels):
        super().__init__()
        self.block = nn.Sequential(
            ConvBlock(channels, channels, kernel_size=3, padding=1, stride=1),
            ConvBlock(channels, channels, kernel_size=3, padding=1, use_act=False)
        )
    
    def forward(self, x):
        return x + self.block(x)

# %%
class Generator(nn.Module):
    def __init__(self, img_channels, num_residuals=9, num_features=64):
        super().__init__()
        self.initial = nn.Sequential(
            nn.Conv2d(img_channels, num_features, kernel_size=7, stride=1, padding=3, padding_mode="reflect"),
            nn.InstanceNorm2d(num_features),
            nn.ReLU(inplace=True)
        )
        
        self.down_blocks = nn.ModuleList([
            ConvBlock(num_features, num_features * 2, kernel_size=3, stride=2, padding=1),
            ConvBlock(num_features * 2, num_features * 4, kernel_size=3, stride=2, padding=1)
        ])
        
        self.residual_blocks = nn.Sequential(*[
            ResidualBlock(num_features * 4) for _ in range(num_residuals)
        ])
        
        self.up_blocks = nn.ModuleList([
            ConvBlock(num_features * 4, num_features * 2, down=False, kernel_size=3, stride=2, padding=1, output_padding=1),
            ConvBlock(num_features * 2, num_features * 1, down=False, kernel_size=3, stride=2, padding=1, output_padding=1),
        ])
        
        self.last = nn.Conv2d(num_features * 1, img_channels, kernel_size=7, stride=1, padding=3, padding_mode="reflect")
        
    def forward(self, x):
        x = self.initial(x)
        for layer in self.down_blocks:
            x = layer(x)
        x = self.residual_blocks(x)
        for layer in self.up_blocks:
            x = layer(x)
        return torch.tanh(self.last(x))

# %%
def test():
    img_channels = 3
    img_size = 256
    x = torch.randn((2, img_channels, img_size, img_size))
    gen = Generator(img_channels, 9)
    print(gen(x).shape)

test()
# Out:
# torch.Size([2, 3, 256, 256])

# %%
class HorseZebraDataset(Dataset):
    def __init__(self, zebra, horse, transform=None):
        self.horse = horse
        self.zebra = zebra
        self.transform = transform
        
        self.horse_images = os.listdir(horse)
        self.zebra_images = os.listdir(zebra)
        self.dataset_length = max(len(self.horse_images), len(self.zebra_images))
        self.horse_length = len(self.horse_images)
        self.zebra_length = len(self.zebra_images)
        
    def __len__(self):
        return self.dataset_length

    def __getitem__(self, index):
        zebra_img = self.zebra_images[index % self.zebra_length]
        horse_img = self.horse_images[index % self.horse_length]
        
        horse_path = os.path.join(self.horse, horse_img)
        zebra_path = os.path.join(self.zebra, zebra_img)
        
        zebra_img = np.array(Image.open(zebra_path).convert("RGB"))
        horse_img = np.array(Image.open(horse_path).convert("RGB"))
        
        if self.transform:
            augmentations = self.transform(image=horse_img, image0=zebra_img)
            horse_img = augmentations["image"]
            zebra_img = augmentations["image0"]
        
        return horse_img, zebra_img

# %%
# Configs

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
TRAIN_DIR = "data/train"
VAL_DIR = "data/val"
BATCH_SIZE = 1
LEARNING_RATE = 2e-4
LAMBDA_IDENTITY = 0.0
LAMBDA_CYCLE = 10
NUM_WORKERS = 4
NUM_EPOCHS = 45
LOAD_MODEL = False
SAVE_MODEL = True
HORSE_GEN_CHECKPOINT = "hgen.pth.tar"
ZEBRA_GEN_CHECKPOINT = "zgen.pth.tar"
HORSE_DISC_CHECKPOINT = "hdisc.pth.tar"
ZEBRA_DISC_CHECKPOINT = "zdisc.pth.tar"

transforms = A.Compose(
    [
        A.Resize(width=256, height=256),
        A.HorizontalFlip(p=0.5),
        A.ColorJitter(p=0.1),
        A.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5], max_pixel_value=255),
        ToTensorV2(),
    ],
    additional_targets={"image0": "image"},
)

# %%
def save_checkpoint(model, optimizer, filename="my_checkpoint.pth.tar"):
    print("-> Saving checkpoint")
    checkpoint = {
        "state_dict": model.state_dict(),
        "optimizer": optimizer.state_dict()
    }
    torch.save(checkpoint, filename)


def load_checkpoint(checkpoint_file, model, optimizer, lr):
    print("-> Loading checkpoint")
    checkpoint = torch.load(checkpoint_file, map_location=DEVICE)
    model.load_state_dict(checkpoint["state_dict"])
    optimizer.load_state_dict(checkpoint["optimizer"])
    
    for param_group in optimizer.param_groups:
        param_group["lr"] = lr
        

def seed_everything(seed=42):
    os.environ["PYTHONASHSEED"] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = Trie
    torch.backends.cudnn.benchmark = False

# %%
save_count = 0

def train_fn(h_disc, z_disc, h_gen, z_gen, loader, disc_opt, gen_opt, l1,
            mse, d_scaler, g_scaler):
    global save_count
    loop = tqdm(loader, leave=True)
    
    fake_horses = 0
    real_horses = 0

    for idx, (horse, zebra) in enumerate(loop):
        horse = horse.to(DEVICE)
        zebra = zebra.to(DEVICE)

        # train descriminators
        with torch.cuda.amp.autocast():
            fake_horse = h_gen(zebra)
            real_horse_disc = h_disc(horse)
            fake_horse_disc = h_disc(fake_horse.detach())
            real_horses += real_horse_disc.mean().item()
            fake_horses += fake_horse_disc.mean().item()
            real_horse_disc_loss = mse(real_horse_disc, torch.ones_like(real_horse_disc))
            fake_horse_disc_loss = mse(fake_horse_disc, torch.zeros_like(fake_horse_disc))
            horse_disc_loss = real_horse_disc_loss + fake_horse_disc_loss


            fake_zebra = z_gen(horse)
            real_zebra_disc = z_disc(zebra)
            fake_zebra_disc = z_disc(fake_zebra.detach())

            real_zebra_disc_loss = mse(real_zebra_disc, torch.ones_like(real_zebra_disc))
            fake_zebra_disc_loss = mse(fake_zebra_disc, torch.zeros_like(fake_zebra_disc))
            zebra_disc_loss = real_zebra_disc_loss + fake_zebra_disc_loss

            disc_loss = (zebra_disc_loss + horse_disc_loss) / 2

        opt_disc.zero_grad()
        d_scaler.scale(disc_loss).backward()
        d_scaler.step(opt_disc)
        d_scaler.update()

        with torch.cuda.amp.autocast():
            # adversarial loss
            fake_horse_disc = h_disc(fake_horse)
            fake_zebra_disc = z_disc(fake_zebra)
            horse_gen_loss = mse(fake_horse_disc, torch.ones_like(fake_horse_disc))
            zebra_gen_loss = mse(fake_zebra_disc, torch.ones_like(fake_zebra_disc))

            # cycle loss
            cycled_zebra = z_gen(fake_horse) # fake horse is a horse generated from a zebra
            cycled_horse = h_gen(fake_zebra) # we generate a horse from a zebra image that is generated from a horse image. Should be the same
            cycled_zebra_loss = l1(zebra, cycled_zebra) # the diference between the original zebra image and the cyceled_zebra.
            cycled_horse_loss = l1(horse, cycled_horse)

            # identity loss
            zebra_identity = z_gen(zebra)
            horse_identity = h_gen(horse)
            zebra_identity_loss = l1(zebra, zebra_identity)
            horse_identity_loss = l1(horse, horse_identity)

            gen_loss = (
                horse_gen_loss + zebra_gen_loss
                + (cycled_zebra_loss * LAMBDA_CYCLE)
                + (cycled_horse_loss * LAMBDA_CYCLE)
                + (horse_identity_loss * LAMBDA_IDENTITY)
                + (zebra_identity_loss * LAMBDA_IDENTITY)
            )

        opt_gen.zero_grad()
        g_scaler.scale(gen_loss).backward()
        g_scaler.step(opt_gen)
        g_scaler.update()
        
        if idx % 200 == 0:
            save_image(fake_horse * 0.5 + 0.5, f"horse_{idx}_{save_count}.png")
            save_image(fake_zebra * 0.5 + 0.5, f"zebra_{idx}_{save_count}.png")
            save_count = save_count + 1

        loop.set_postfix(real_horse=real_horses / (idx + 1), fake_horse=fake_horses / (idx + 1))

# %%
h_disc = Discriminator(in_channels=3).to(DEVICE)
z_disc = Discriminator(in_channels=3).to(DEVICE)
h_gen = Generator(img_channels=3, num_residuals=9).to(DEVICE)
z_gen = Generator(img_channels=3, num_residuals=9).to(DEVICE)
opt_disc = optim.Adam(
    list(h_disc.parameters()) + list(z_disc.parameters()),
    lr=LEARNING_RATE,
    betas=(0.5, 0.999),
)

opt_gen = optim.Adam(
    list(z_gen.parameters()) + list(h_gen.parameters()),
    lr=LEARNING_RATE,
    betas=(0.5, 0.999),
)


L1 = nn.L1Loss()
mse = nn.MSELoss()

if LOAD_MODEL:
    load_checkpoint(
        HORSE_GEN_CHECKPOINT,
        h_gen,
        opt_gen,
        LEARNING_RATE,
    )
    load_checkpoint(
        ZEBRA_GEN_CHECKPOINT,
        z_gen,
        opt_gen,
        LEARNING_RATE,
    )
    load_checkpoint(
        HORSE_DISC_CHECKPOINT,
        h_disc,
        opt_disc,
        LEARNING_RATE,
    )
    load_checkpoint(
        ZEBRA_DISC_CHECKPOINT,
        z_disc,
        opt_disc,
        LEARNING_RATE,
    )
    
    
dataset = HorseZebraDataset(
    horse="/kaggle/input/horse2zebra-dataset/trainA",
    zebra="/kaggle/input/horse2zebra-dataset/trainB",
    transform=transforms,
)
val_dataset = HorseZebraDataset(
    horse="/kaggle/input/horse2zebra-dataset/testA",
    zebra="/kaggle/input/horse2zebra-dataset/testB",
    transform=transforms,
)
val_loader = DataLoader(
    val_dataset,
    batch_size=1,
    shuffle=False,
    pin_memory=True,
)
loader = DataLoader(
    dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=NUM_WORKERS,
    pin_memory=True,
)
g_scaler = torch.cuda.amp.GradScaler()
d_scaler = torch.cuda.amp.GradScaler()

for epoch in range(NUM_EPOCHS):
    train_fn(h_disc, z_disc, z_gen, h_gen, loader, opt_disc, opt_gen, L1, mse, d_scaler, g_scaler,)

    if SAVE_MODEL:
        save_checkpoint(h_gen, opt_gen, filename=HORSE_GEN_CHECKPOINT)
        save_checkpoint(z_gen, opt_gen, filename=ZEBRA_GEN_CHECKPOINT)
        save_checkpoint(h_disc, opt_disc, filename=HORSE_DISC_CHECKPOINT)
        save_checkpoint(h_disc, opt_disc, filename=ZEBRA_DISC_CHECKPOINT)
# Out:
# /opt/conda/lib/python3.10/site-packages/torch/cuda/amp/grad_scaler.py:120: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
#   0%|          | 0/1334 [00:00<?, ?it/s]/opt/conda/lib/python3.10/site-packages/torch/amp/autocast_mode.py:204: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#  65%|██████▍   | 865/1334 [4:56:53<2:40:55, 20.59s/it, fake_horse=0.43, real_horse=0.562]
